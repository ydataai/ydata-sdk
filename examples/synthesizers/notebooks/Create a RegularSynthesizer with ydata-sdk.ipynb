# %% [markdown]
# # Create a synthesizer using ydata-sdk

# %% [markdown]
# #### Ensure authentication

# %%
import os

os.environ['YDATA_TOKEN']='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYW1lIjoiRmFiaWFuYSBDbGVtZW50ZSIsImVtYWlsIjoiZmFiaWFuYS5jbGVtZW50ZUB5ZGF0YS5haSIsImV4cCI6MTcxNzY5MDQzMywiaWF0IjoxNzE3NjA0MDMzfQ.tPvYV4cclgnDkDut-eXx9U4AmESBT8dKmApk_6q9yoU'
os.environ['YDATA_VERIFY_SSL']='0'

# %% [markdown]
# #### From an existing datasource
#
# Follow one of the following get-started tutorial to: create a [Datasource from a CSV file](https://docs.sdk.ydata.ai/latest/get-started/upload_csv/) or [from an existing storage](https://docs.sdk.ydata.ai/latest/get-started/create_multitable_dataset/).
#
# After creating succesfully the datasource, you are now able to get its id as shown in the image below
# ![image.png](attachment:a7dbc68f-ca91-4cf2-9484-cc602b1d56e3.png)

# %%
from ydata.sdk.datasources import DataSource
from ydata.sdk.synthesizers import RegularSynthesizer

# %% [markdown]
# Paste the copied ID in the code snippet below.

# %%
X = DataSource.get('697ace0b-7f6b-4f2c-9b23-f118c0727f34')

# %% [markdown]
# ## Train and sample from a Synthetic Data Generator

# %%
# We initialize a regular synthesizer
# As long as the synthesizer does not call `fit`, it exists only locally
synth = RegularSynthesizer(name='Synthetic data generator - from SDK')

# We train the synthesizer on our dummy dataset
synth.fit(X=X)

# %% [markdown]
# #### Sample a synthetic sample

# %%
## Sample new data
sample = synth.sample(1000)

# %%
sample
# Out:
#      cancer  population
# 0         4        3706
# 1        19        1098
# 2         7        7408
# 3        20        7025
# 4        23        7760
# ..      ...         ...
# 995       4        3470
# 996      19        2317
# 997     179       13142
# 998      41       10416
# 999      24       12775
#
# [1000 rows x 2 columns]
